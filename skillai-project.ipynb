# %% [markdown]
# # GenAI powered skill explorer for students and professionals
#
# ## Introduction
# In this notebook we experiment with the use of LLMs for helping students and professionals seeking to improve skills for a specific job role. SkillSensei is meant to help by:
#
# - **Matching job roles with trainable skills:** Identify appropriate roles and career avenues based on personal skills and professional skills.
#
# ## Table of Contents:
# This notebook is separated into the follwing sections
#
# - **Section 1: Setup**
# - **Section 2: Initial experimentation**
# - **Section 3: Introducing RAG**
# - **Section 4: Evaluation**
#
# ## Concepts from the course:
# In this notebook, we explore the following concepts from the LLM Foundations course:
#
# - Structured output/JSON mode/controlled generation
# - Few-shot prompting
# - Gen AI evaluation
# - Embeddings
# - Retrieval augmented generation (RAG)
# - Vector search/vector store/vector database

# %% [markdown]
# # Section 1: Setup

# %% [markdown]
# Install the SDK

# %%
# !pip uninstall -qqy jupyterlab  # Remove unused conflicting packages
# !pip install -qU "google-genai==1.7.0" "chromadb==0.6.3"

# %% [markdown]
# Import the SDK and some helpers for rendering the output.

# %%
from google import genai
from google.genai import types
import os
from dotenv import load_dotenv

# %%
from IPython.display import HTML, Markdown, display

# %% [markdown]
# Set up a retry helper. This allows you to "Run all" without worrying about per-minute quota.

# %%
from google.api_core import retry


is_retriable = lambda e: (isinstance(e, genai.errors.APIError) and e.code in {429, 503})

genai.models.Models.generate_content = retry.Retry(
    predicate=is_retriable)(genai.models.Models.generate_content)

# %% [markdown]
# ## Set up your API key
# To run the following cell, your API key must be stored it in a Kaggle secret named **GOOGLE_API_KEY**.
#
# If you don't already have an API key, you can grab one from [AI Studio](https://aistudio.google.com/apikey).
#
# To make the key available through Kaggle secrets, choose Secrets from the Add-ons menu and follow the instructions to add your key or enable it for this notebook.

# %%
load_dotenv()

GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')


# from kaggle_secrets import UserSecretsClient

# GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")

# %% [markdown]
# # Section 2: Initial exploration
# Let's begin by exploring the Gemini's capabilities to provide career advice, by trying out a few simple prompts, and experimenting with Chain of Though and ReAct.

# %%
from pprint import pprint

client = genai.Client(api_key=GOOGLE_API_KEY)

# for model in client.models.list():
#     pprint(f"{model.display_name}: {model.description}")

# %% [markdown]
# ## Prompting techniques

# %%
model_config = types.GenerateContentConfig(
    # These are the default values for gemini-2.0-flash.
    temperature=1.0,
    top_p=0.95,
)

zero_shot_prompt = """You are an career advisor focusing on skills. Provide a list of the most relevant skills for each of the following jobs: data engineer, school teacher, barber, and software engineer.:
Most relevant skills: """

response = client.models.generate_content(
    model='gemini-2.0-flash',
    config=model_config,
    contents=zero_shot_prompt)

Markdown(response.text)
# Out:
# Okay, here's a breakdown of the most relevant skills for each of the listed jobs, keeping in mind that specific requirements can vary based on industry, location, and seniority:
#
# **1. Data Engineer**
#
# *   **Technical/Hard Skills:**
#
#     *   **Data Modeling:** Designing efficient and scalable data structures (schemas, tables, etc.)
#     *   **ETL (Extract, Transform, Load) Processes:** Building and maintaining pipelines to move and transform data from various sources.
#     *   **Data Warehousing:** Experience with data warehouse solutions (e.g., Snowflake, Redshift, BigQuery).
#     *   **Database Management Systems (DBMS):** Proficiency in SQL and NoSQL databases (e.g., MySQL, PostgreSQL, MongoDB, Cassandra).
#     *   **Cloud Computing:** Expertise with cloud platforms (e.g., AWS, Azure, GCP) and their data-related services.
#     *   **Programming Languages:** Strong skills in Python and/or Java/Scala.
#     *   **Big Data Technologies:** Familiarity with Hadoop, Spark, Kafka, etc., for processing large datasets.
#     *   **Data Governance:** Understanding and implementing data quality, security, and compliance measures.
#     *   **Operating Systems:** Knowledge of Linux and/or Unix based platforms.
#     *   **Version Control:** Git and other version control systems.
# *   **Soft Skills:**
#
#     *   **Problem-Solving:** Ability to identify and resolve data-related issues effectively.
#     *   **Analytical Thinking:** Analyzing data requirements and designing appropriate solutions.
#     *   **Communication:** Clearly explaining technical concepts to both technical and non-technical audiences.
#     *   **Collaboration:** Working effectively with data scientists, analysts, and other stakeholders.
#     *   **Attention to Detail:** Ensuring data accuracy and integrity.
#     *   **Adaptability:** Keeping up-to-date with evolving technologies and data trends.
#     *   **Time Management:** Ability to manage work load to effectively meet deadlines.
#
# **2. School Teacher**
#
# *   **Technical/Hard Skills:**
#
#     *   **Curriculum Development:** Creating and implementing engaging and effective lesson plans.
#     *   **Subject Matter Expertise:** Strong knowledge of the subject(s) being taught.
#     *   **Classroom Management:** Creating a positive and productive learning environment.
#     *   **Assessment:** Designing and administering assessments (tests, quizzes, projects) to evaluate student learning.
#     *   **Educational Technology:** Using technology tools and platforms to enhance teaching and learning (e.g., learning management systems, educational apps).
#     *   **Differentiated Instruction:** Adapting teaching methods to meet the diverse needs of students.
#     *   **Reporting:** Effectively summarizing student progress to present to parents/guardians.
# *   **Soft Skills:**
#
#     *   **Communication:** Communicating effectively with students, parents, and colleagues.
#     *   **Patience:** Maintaining a calm and supportive demeanor, especially when dealing with challenging students.
#     *   **Empathy:** Understanding and responding to students' emotional needs.
#     *   **Creativity:** Developing innovative and engaging lessons and activities.
#     *   **Organization:** Managing classroom materials, schedules, and student records.
#     *   **Leadership:** Guiding and motivating students to achieve their learning goals.
#     *   **Adaptability:** Adjusting teaching strategies based on student progress and classroom dynamics.
#     *   **Problem Solving:** Effectively deal with any classroom issues.
#
# **3. Barber**
#
# *   **Technical/Hard Skills:**
#
#     *   **Haircutting:** Proficiency in various cutting techniques (e.g., fades, tapers, layers).
#     *   **Shaving:** Expertise in shaving techniques, including straight razor shaving (where permitted).
#     *   **Styling:** Ability to style hair using different products and techniques.
#     *   **Beard Trimming & Shaping:** Skill in trimming and shaping beards to complement facial features.
#     *   **Hair Coloring:** Knowledge of hair coloring techniques and products.
#     *   **Sanitation & Hygiene:** Following strict hygiene protocols to maintain a clean and safe work environment.
#     *   **Tool Maintenance:** Properly cleaning, sanitizing, and maintaining barbering tools.
# *   **Soft Skills:**
#
#     *   **Customer Service:** Providing excellent service and building rapport with clients.
#     *   **Communication:** Listening to clients' needs and providing clear explanations of services.
#     *   **Attention to Detail:** Ensuring precision and accuracy in haircuts and other services.
#     *   **Creativity:** Suggesting styles and looks that suit clients' individual features.
#     *   **Interpersonal Skills:** Building relationships with clients and creating a welcoming atmosphere.
#     *   **Time Management:** Managing appointments and completing services efficiently.
#     *   **Physical Stamina:** Standing for extended periods and performing repetitive motions.
#     *   **Sales:** Promoting and recommending products and services to clients.
#
# **4. Software Engineer**
#
# *   **Technical/Hard Skills:**
#
#     *   **Programming Languages:** Proficiency in one or more languages (e.g., Python, Java, C++, JavaScript, C#).
#     *   **Data Structures and Algorithms:** Understanding fundamental data structures (e.g., arrays, linked lists, trees) and algorithms (e.g., sorting, searching).
#     *   **Software Design Principles:** Knowledge of design patterns, SOLID principles, and other software design concepts.
#     *   **Version Control:** Using Git and other version control systems for collaborative development.
#     *   **Testing:** Writing unit tests, integration tests, and other types of tests to ensure code quality.
#     *   **Debugging:** Identifying and resolving software bugs efficiently.
#     *   **Databases:** Working with relational and/or NoSQL databases.
#     *   **Operating Systems:** Understanding operating system concepts and working with different OS environments (e.g., Linux, Windows, macOS).
#     *   **Web Development:** (If applicable) Knowledge of front-end (HTML, CSS, JavaScript) and/or back-end technologies (e.g., Node.js, Python frameworks like Django or Flask, Java frameworks like Spring).
#     *   **Cloud Computing:** (Increasingly important) Familiarity with cloud platforms and services.
# *   **Soft Skills:**
#
#     *   **Problem-Solving:** Breaking down complex problems into smaller, manageable tasks.
#     *   **Analytical Thinking:** Analyzing requirements and designing effective solutions.
#     *   **Communication:** Clearly communicating technical concepts to both technical and non-technical audiences.
#     *   **Collaboration:** Working effectively in a team environment.
#     *   **Time Management:** Meeting deadlines and managing workload effectively.
#     *   **Adaptability:** Learning new technologies and adapting to changing project requirements.
#     *   **Attention to Detail:** Writing clean, well-documented, and error-free code.
#     *   **Continuous Learning:** Staying up-to-date with the latest technologies and trends.
#
# Remember that this is not an exhaustive list, and the specific skills required for each job may vary depending on the specific role and employer. However, these are some of the most important and relevant skills to focus on. Good luck!

# %% [markdown]
# While this list is already quite extensive, there are a few things to note. First, while the zero shot prompt only mentioned "most relevant" skills, the LLM generated more than just skills. For example, it also generated qualities such as "strength and lifting capacity" which while are trainable, can be thought of as physical qualities rather than skills. Second, while it provided a structured answer (i.e., grouped skills and qualities in groups) it generated an answer which can be too broad and overwhelming for a user. Instead we want, {NAME} to provide more focused skills to users.

# %%
import typing_extensions as typing
import json

class JobSkills(typing.TypedDict):
    skills: list[str]
    descriptions: list[str]

few_shot_prompt = """Based on a job title provide a list of skills and descriptions in valid JSON :

EXAMPLE:
astronaut
JSON Response:
```
{
skills: ["STEM Proficiency", "Leadership", "Giving First Aid", "Data Analysis & Interpretation"]
descriptions: ["Strong foundation in science, technology, engineering, and mathematics (physics, chemistry, biology, astronomy, computer science, engineering principles)", "Taking initiative, making sound judgments, and leading effectively in critical situations.", "Basic medical training to handle emergencies and provide first aid in isolated environments", "Analyzing data from experiments, observations, and equipment monitoring"]
}
```

EXAMPLE:
school teacher
JSON Response:
```
{
"skills": ["Presentation Skills", "Curriculum Development", "Deep Content Knowledge", "Assessment & Evaluation", "Classroom Managment"]
"descriptions": ["Ability to present information clearly, engagingly, and effectively.", "Ability to create engaging and effective lesson plans and educational materials.", "A thorough understanding of the subject(s) being taught.", "Ability to design and administer assessments, analyze student performance, and provide constructive feedback.", "Planning lessons, managing resources, and tracking student progress efficiently.",]
}
```

systems administrator
"""

baseline_response = client.models.generate_content(
    model='gemini-2.0-flash',
    config=types.GenerateContentConfig(
        response_mime_type="application/json",
        response_schema=JobSkills,
    ),
    contents=few_shot_prompt)

data = json.loads(baseline_response.text)

for i in range(len(data.get("skills"))):
    print(data.get("skills")[i], ": ", data.get("descriptions")[i])
# Out:
# Operating Systems :  Proficiency in managing and maintaining various operating systems (Windows, Linux, macOS).
# Network Administration :  Configuring and maintaining network infrastructure, including routers, switches, and firewalls.
# Scripting :  Ability to write scripts in languages like Python, Bash, or PowerShell to automate tasks.
# Troubleshooting :  Identifying and resolving hardware, software, and network issues.
# Automation :  Automating repetitive tasks using tools and scripts to improve efficiency and reduce errors

# %% [markdown]
# This is an improvement over the zero shot prompting, as it provides a short list of skills a person can focus on. The use of json for the output, also it more structured and easily parsable by other tools. One thing to notice is however, that the model could have learned to limit the output to four skills per prompt, because both examples include four skills. While the focused scope is not necessarily a disadvantage, we don't know how the model prioritizes the selected skills.

# %% [markdown]
# # Section 3: Introducing RAG
#
# Now let's explore how the listed skills compare, once we use a vectorized dataset containing job listings and their relevant skills scrapped from Linkedin during 2024.
#
# ## The dataset
# As the entire dataset contains 1.3M Jobs and Skills we will use just a subset of the data. The full dataset is available on Kaggle: [1.3M Linkedin Jobs & Skills (2024)](https://www.kaggle.com/datasets/asaniczka/1-3m-linkedin-jobs-and-skills-2024?select=linkedin_job_postings.csv)

# %%
import pandas as pd

# Load the CSVs
job_postings_df = pd.read_csv("./archive/linkedin_job_postings.csv", nrows=20000)
skills_df = pd.read_csv("./archive/job_skills.csv", nrows=20000)

job_postings_small_df = job_postings_df[["job_link", "job_title"]]

# Optional: clean nulls
skills_df.dropna(inplace=True)
#summary_df.dropna(inplace=True)

# %%
# Merge on job_link
merged_df = pd.merge(job_postings_small_df, skills_df, on='job_link', how='inner')

#merged_df = pd.merge(merged_df, skills_df, on='job_link', how='inner')

merged_df.head(7)
# Out:
#                                             job_link  \
# 0  https://www.linkedin.com/jobs/view/systems-adm...
# 1  https://www.linkedin.com/jobs/view/enrollment-...
# 2  https://www.linkedin.com/jobs/view/senior-risk...
# 3  https://www.linkedin.com/jobs/view/prosthodont...
# 4  https://www.linkedin.com/jobs/view/veterinary-...
# 5  https://www.linkedin.com/jobs/view/senior-stru...
# 6  https://www.linkedin.com/jobs/view/field-techn...
#
#                                            job_title  \
# 0                              Systems Administrator
# 1                    Enrollment Specialist Team Lead
# 2  Senior Risk Manager, Interest Rate Risk in the...
# 3                        Prosthodontist/Periodontist
# 4                            Veterinary Receptionist
# 5                         Senior Structures Engineer
# 6                                   Field Technician
#
#                                           job_skills
# 0  Windows computing, Server 2012, Software troub...
# 1  Customer service, Goal achievement, Teamwork, ...
# 2  Interest Rate Risk Management, Asset Liability...
# 3  Prosthodontics, Periodontics, Stateoftheart di...
# 4  Customer service, Organizational skills, Commu...
# 5  CSiBridge, Conspan, RC Pier, BRASS, MDX, Highw...
# 6  Communication skills, Ability to work at heigh...

# %%
# Combine job_summary and job_skills into one field
merged_df['text_to_embed'] = (
    "Title: " + merged_df['job_title'].astype(str).str.strip() + "\n" +
    "Skills: " + merged_df['job_skills'].astype(str).str.strip()
)

documents = merged_df['text_to_embed'].tolist()

# %%
documents
# Out:
# ["Title: Systems Administrator\nSkills: Windows computing, Server 2012, Software troubleshooting, Analytical thinking, Problem solving, PowerShell, Customer service, Microsoft Office 365, Azure AD, SharePoint, Security and Compliance Center, Teams, MCSE, MCSA, Bachelor's degree",
#  "Title: Enrollment Specialist Team Lead\nSkills: Customer service, Goal achievement, Teamwork, Communication, Retail knowledge, Sales optimization, Product knowledge, Competitive environment, Team meetings, Hourly wage, Medical coverage, Dental coverage, Vision coverage, Paid time off, Advancement opportunities, Physical ability, Driver's license, Lifting",
#  'Title: Senior Risk Manager, Interest Rate Risk in the Banking Book - Hybrid\nSkills: Interest Rate Risk Management, Asset Liability Management, Balance Sheet Management, Treasury/Finance, Risk Management, Risk Quantification, Risk Governance, Risk Controls, Forecasting, Risk Reporting, Risk Identification, Risk Policies, Risk Limits, Risk Appetite, Stress Testing, ICAAP, CCAR, Economics, Math, Hard Sciences, Board Communications, Regulatory Communications, Influencing, DecisionMaking, Negotiation, Detail oriented, Handson management, Innovation, Communication, Collaboration',
#  'Title: Prosthodontist/Periodontist\nSkills: Prosthodontics, Periodontics, Stateoftheart diagnostic tools, Technology, Multidisciplinary team, Comprehensive treatment plans, Patientcentric approach, DMD or DDS degree, Board certification in Prosthodontics and/or Periodontics, New York dental licensure, Highquality prosthodontic and periodontic care, Interpersonal and communication skills, Collaboration, Innovation, Diversity of thought, Strong execution',
#  'Title: Veterinary Receptionist\nSkills: Customer service, Organizational skills, Communication skills, Tech Savvy, Data entry, Scheduling, Filing, Retail sales, High school diploma',
#  'Title: Senior Structures Engineer\nSkills: CSiBridge, Conspan, RC Pier, BRASS, MDX, Highway Bridges, PS&E, Transportation Projects, Design Build and Alternative Delivery, NDOT, Clark County, Medical Dental Vision Life and Disability Insurance, Generous Paid Time Off, 401(k) with no vesting period, Professional Development Opportunities, Paid Professional Organization Membership, Professional Licensure',
#  "Title: Field Technician\nSkills: Communication skills, Ability to work at heights, Lifting over 70 lbs, Valid driver's license, Clean driving record, Willingness to travel",
#  'Title: Retail Associate\nSkills: Retail, Customer service, Sales, Cleaning, Merchandising, Loss prevention, Cash handling, PDT, Register, PC, Safety, Communication, Teamwork, Problem solving, Adaptability, Physical strength, Stockroom, Supervisory',
#  'Title: Pilot (Part-time/Per Diem) - Life Lion\nSkills: Rotorcraft operation, Flight planning, Loading and securing aircraft, Minimum associate\'s degree or equivalent in aircraft operation, FAA Commercial pilot certificate with rotorcraft and helicopter instrument rating, Minimum 2000 hours total flight time 3000 preferred, EMS or military medevac flight experience preferred, AS365 series and/or H155 model experience preferred, Ability to meet "PilotinCommand" qualifications in accordance with FAR Part 135, Airline Transport Pilot certificate preferred',
#  'Title: Customer Service Representative\nSkills: Customer service, Communication, Problem solving, MS Office, CRM software, Order processing, Order fulfillment, Product knowledge, Upselling, Crossselling, Feedback collection, Construction industry terminology',
#  'Title: Manager of Operational Excellence Strategy\nSkills: Project Management, Strategic Thinking, Data Analysis, Problem Solving, Process Improvement, Scalable Processes, Education, Equity, Diversity, Team Collaboration, Feedback, Mindfulness, DEIJ, Macbook Air, 403(b) Retirement Plan, Comprehensive Medical Dental Vision Plans, Flexible Spending Accounts, Competitive Compensation, Monthly Reimbursement for Mobile Phone, Team Outings',
#  'Title: Field Chemist\nSkills: Waste Management, Lab Pack, Chemical Waste, OSHA 40, Environmental Science, Chemistry, Hazardous Waste, Environmental Safety, Environmental Compliance, Microsoft Office, Communication, Customer Service, Field Work, Regulatory Compliance, Diversity, Equity, Inclusion',
#  'Title: Senior Secretary - Dental Hygiene\nSkills: Administrative Support, Dental Hygiene Knowledge, Microsoft Office Suite (Word Excel PowerPoint), Eaglesoft, Typhon, College Database, Accreditation Processes, Customer and Student Relationship Building, Organizational Skills, Interpersonal Skills, Written Communication, Verbal Communication, Liaison for Programs, Work Flexibility',
#  'Title: Cafe Manager\nSkills: Kitchen Management, Inventory Control, Food Handling Certification, Team Leadership, ProblemSolving, Communication Skills, Decision Making, Personal Accountability, Time Management, Customer Service, Physical Endurance',
#  'Title: Billing Specialist\nSkills: Billing, SAP, Customer Service, Communication, Organization, Microsoft Word, Microsoft Excel, Microsoft Outlook, SAP Business One',
#  "Title: Technical Sales Associate\nSkills: Technical Sales, Sales, Equipment Sales, Sales Goals, Time Management, Independent Work, Relationship Building, Customer Relations, Engineering, Science, Bachelor's Degree",
#  "Title: Senior Accountant (135436)\nSkills: Senior Accountant, Tampa FL, Microsoft Office Suite, MS SharePoint, MRP Systems, Inventory control, Valuation calculations, Variance analysis, Journal entries, Account reconciliations, Rollforwards, Excess and obsolete inventory, Financial audits, Procedural improvements, Generally accepted accounting principles, Accounting, Finance, Bachelor's degree, Medical, Dental, Vision, 401K, PTO, 4day work week",
#  'Title: Long Term (Travel) Intensive Care Unit - ICU RN - 24147510EXPPLAT /\nSkills: ICU RN, Critical Care RN, Compact License, Medical Dental Vision Insurance, 401(k) Savings Program, Licensure and Credential Reimbursements, Professional Liability / Malpractice Coverage, Weekly Pay with Direct Deposit, Tax Free Per Diems, Furnished Housing accommodations, Nurse Staffing, Travel Nurse, Temporary Placement, Permanent Placement, Qualified Nurses, US Regions',
#  'Title: Sr. Principal Systems Engineer - Electronic Warfare & Communications Systems\nSkills: Systems Engineering, Data Analysis, Digital Signal Processing, Electronic Warfare, Communication Systems, RF (Radio Frequency) engineering, Signal processing, Digital communication systems, MATLAB, Python, C, C++, ModelBased Systems Engineering (MBSE), System Modeling Language (SysML), Sensor Open Systems Architecture (SOSA), System requirements, System architecture, System design, System simulations, System models, System algorithms, System integration, System performance, System documentation, Trade studies, Risk assessments, Emerging technologies, Crossfunctional teams, Hardware, Software, Test engineers, Training, Functional leadership, Technical leadership',
#  "Title: Citation CJ3 Captain\nSkills: Captain, Citation CJ3, Part 135, Compensation: $120000.00  $130000.00, Total Time  3000 hours, Total PIC  2000 hours, Total Time in Type  250 hours, Total MultiEngine  1500 hours, Total MultiEngine PIC  500 hours, Total Turbine  500 hours, Strong Customer Service and Communication Skills, Proactive decisionmaking skills, Valid U.S. driver's license, Preemployment drug screen, Preemployment background check, 1st Class Medical, FCC Restricted Radio License, Proof of eligibility to work in the US, Current passport, Initial or Recurrent 142 training, ATP, EmployerPaid Medical, Dental Vision and Life Insurance, HSA/FSA Options, Short/Long Term Disability Options, 401K with Company Match, Uniform Allowance, Company Issued iPad",
#  "Title: Pursuit Manager\nSkills: Pursuit Management, Client and Opportunity Research, Proposal and Presentation Development, Regional/District Support, National Initiatives, Bachelor's degree, 12 years’ experience, Verbal and written communication skills, Critical thinking, Client development, Marketing strategy development, Group facilitation, Teamwork, Strategic thinking/leadership, Sound judgment, Strategic capture plans, Engagement at a strategic highlevel, Experiencebased judgement, Critical thinking skills, Strong leadership skills, Influence others, Work with all levels of management staff, Facilitation and leadership skills, Microsoft Office, Adobe Creative Suite, SharePoint, Communicationsrelated software programs, Institutional knowledge of WSP’s national and global resources, Experience on various contract types, Clients, Delivery methods, Alternative delivery (design/build and P3), Energy and excitement, Team approach, Consensus/alignment",
#  'Title: Sr Billing Specialist\nSkills: Closeout Billings, Financial Reports, Government Contracts, Federal Government Contract Types, Cost Types, Time & Material (T&M), Cost Plus Fixed Fee (CPFF), Level of Effort (LOE), Firm Fixed Price (FFP), CLIN/SLIN/ACRN Structure, Costpoint, Unbilled Receivables, Legacy Data Warehouse, Invoicing, Billing Discrepancies, Billing Cycle Times, Collections, DSO, Process Improvement, Internal Controls, Reporting, Adhoc Reporting',
#  'Title: SAP Architect\nSkills: Agile methodologies, SAP, Financial reporting, Portfolio validation, Strategic financial planning, Financial analysis, Project management, Business process design and architecture, Business requirements and solution design, Endtoend SAP design, System integration, Testing and conversion activities, Higher education, Industry certification, Certified Public Accountant (CPA), Certified Government Financial Manager (CGFM), Certified Defense Financial Manager (CDFM), Project Management Professional (PMP), 401k match (100% vested), Medical Dental Vision insurance (100% paid), Health Savings Account (HSA) contribution, Paid time off (PTO), Flexible Hours, Tuition and certification reimbursement, Growth opportunities',
#  'Title: Technicien(ne) comptable – Comptes Payables\nSkills: Accounts Payable, Financial Analysis, Microsoft Office Suite, Microsoft Excel, Accounting Software, Microsoft Dynamics GP, Hospitality and Restaurant Industry Experience, College Degree in Accounting, 3+ Years Experience in Accounting, Teamwork and Collaboration, Attention to Detail, Professionalism, Autonomy, Discretion',
#  'Title: Host/Cashier\nSkills: Upbeat attitude, Positive personality, Guest greeting, Payment processing, Stocking, Cleaning',
#  'Title: Senior System Engineer\nSkills: System Engineering, P25, DMR, Microwave Networks, Antenna Combining, IP Radio Dispatch, IP Logging Recorders, Radio Programming, BiDirectional Amplifiers, LTE, 5G, DC Power Systems, Battery Back Up, Technical Design, Documentation, Project Management, Field Technician, Site Acceptance Tests, Third Party Vendor Management, Close Out Documentation, Troubleshooting, Electronics Technician, System Technologist, System Manager, Field Service, LMR, RF Systems, Radio Communications, Radio Frequency, Wired/Wireless Communication Systems, IT Systems, Networking Equipment, Wireless Communications, Electronics, Programming, System Diagnostics, Computer Skills, Networking Skills, SelfManagement Skills, People Skills, Customer Service, ProblemSolving Skills, Stress Management, Drivers License, Good Driving Record, Background Check',
#  'Title: Lead Sales Associate\nSkills: Customer service, Sales, Retail, Communication, Teamwork, Problemsolving, Decisionmaking, Adaptability, Continuous learning, High school diploma or GED, 2+ years experience in animal nutrition care/wellness/treatment, 1+ year experience in retail, Basic computer skills, Ability to research information from the Internet, Familiarity with PETCO PetNet and POLARIS system, Certified on all Companion Animal Departments, Nutrition certified, PIJAC certified (California only), Knowledge of grooming salon program certification, Familiarity with dog training class offerings and PCC’s dog training schedule, Familiarity with PCC’s photography and vaccination schedule',
#  'Title: Accountant\nSkills: Financial accounting, Bank reconciliation, Accounts payable, Accounts receivable, Financial statements, Income statement, Balance sheet, Cash flow statement, Financial reporting, Financial management, Internal controls, Regulatory compliance, Auditing, Project management, ProCore, Construction',
#  'Title: First Year Tax Professional\nSkills: Tax preparation, Tax interviews, Customer service, Sales, Marketing, Teamwork, H&R Block Income Tax Course, 3 hours of continuing education requirement, IRS and state requirements, High school diploma, Communication, Fastpaced environment, Minimum 20 hours a week during peak season, 401k Retirement Savings Plan, Employee Stock Purchase Plan, Medical coverage, Mental health support, Coaching, Flexbile/remote opportunities',
#  'Title: Volunteer: Accountant - 990 Form\nSkills: Volunteerism, Nonprofit Organizations, Community Development, Social Services, Form 990, Regulatory Compliance, Documentation',
#  'Title: Graduate Veterinary Surgeon - Graduate Development Programme\nSkills: Veterinary Medicine, Graduate Development Programme, Clinical skills, Nonclinical skills, CPD (Continuing Professional Development), Wellbeing support, RCVS (Royal College of Veterinary Surgeons), VDS (Veterinary Defence Society), BSAVA (British Small Animal Veterinary Association), BVA (British Veterinary Association), Life assurance, Contributory pension scheme, Cycle to work scheme, Diversity and inclusion, Visa sponsorship',
#  'Title: Accountant\nSkills: Accounting, Accounts payable, Accounts receivable, Financial statements, Bank reconciliation, Journal entries, Monthly reports, Bank deposits, Quickbooks, Logistics',
#  'Title: First Year Tax Professional\nSkills: Tax preparation, Customer service, Retail experience, Sales, Marketing, Teamwork, Communication, H&R Block Income Tax Course, Continuing education, High school diploma, Fastpaced environment, IRS and state requirements, Tax prep benefit, 401k Retirement Savings Plan, Employee Stock Purchase Plan, Flexible/remote opportunities, Collaborative teams, Diversity and inclusion',
#  "Title: Sr. Deskside Technician\nSkills: Microsoft Windows, Android, iOS, Software, Hardware, VPN, VDI, Knowledge Base (KB), Ticketing software, SCCM, Intune, Autopilot, Active Directory, Bitlocker, Remote desktop support tools, High School Diploma or equivalent, A+ Certification, Microsoft Certified Professional (MCP), ITIL Foundations, Lean Six Sigma, Troubleshooting, Data migration, User support, Communication, Professionalism, Problemsolving, Teamwork, Flexibility, Adaptability, Ability to work independently, Ability to work oncall, Valid driver's license, Client and internal leadership experience, Escalation Point experience, Training and mentoring experience",
#  'Title: Young Toddler Lead Teacher\nSkills: Communication, Lesson Planning and Curriculum Development, Classroom Management, Childcare, Diapering and Toileting Assistance, Safety and Sanitation, Positive Behavior and Language Modeling, Collaboration, Professional Development',
#  'Title: School Nurse\nSkills: Medical terminology, Anatomy, Symptoms, Diagnoses, Treatments, First aid, Illnesses, Injuries, Nutrition, Arithmetic operations, Word, Excel, Powerpoint, Internet, Outlook, Electronic mail, Problem solving, Work with diverse individuals, Special needs, Oral and written orders, Cooperative working relationships, Blood Borne Pathogens, Occupational Safety and Health regulations, Biology, Chemistry, Health assessment, Public health, School health, Crisis intervention, Health education, Pediatric population, Community setting, School setting, Registered professional nurse (R.N.), Licensed Practical Nurse (LPN), CardioPulmonary Resuscitation (CPR)',
#  'Title: Staff Nurse - Cardiac Cath Lab\nSkills: Scrub Nurse, Circulating Nurse, Nursing, Cardiac Catheterisation, Electrophysiology, Interventional Radiology, Hybrid Theatre, EPIC, Electronic Clinical Systems, English, Nursing registration (First Level), Nursing & Midwifery Council (NMC)',
#  'Title: Resort Executive Chef\nSkills: Culinary Arts, Food Preparation, Food Service Safety, Kitchen Management, Restaurant Management, Staff Training and Development, Team Building, Kitchen Equipment Operation, Computer Software, Customer Service, Communication, Attention to Detail, Time Management, Stress Management, Problem Solving, Leadership, Creativity, Hygiene, Physical Stamina, Adaptability, Work Ethic, Flexibility',
#  "Title: Caregiver - Full Time\nSkills: Caregiving, Personal care, Companionship, Transportation, Medication reminders, Communication, PC operation, Internet access, Webbased training, CNA certification, Driver's license, Automobile insurance, Reliable vehicle, High school diploma or GED, Statemandated Comfort Keepers training, Ability to endure moderate physical exertion, Lifting up to 25 lbs, Business and personal references, Adherence to policies and procedures",
#  'Title: Sr. Electrical Engineer\nSkills: Electrical engineering, UL508a standards, Electrical control panels, AutoCAD, PLC controlled systems, Lean Six Sigma, Reliability, Design of Experiments, GD&T, 5S, HVAC/R systems and controllers',
#  'Title: Software Engineer\nSkills: SQL, Python, Django, HTML, CSS, JavaScript, Bootstrap, Microsoft Visual C# .net, Microsoft Visual Basic .net, VBScript, ETL, SSIS, DTS, Azure DevOps, Production Support, Healthcare, Teamwork, Collaboration, Respect, Member Centric, Honesty, Integrity, Commitment to Service Excellence, Compassion, Empathy, Problem Solving, Initiative, SelfDirected, Flexibility, Adaptability, Communication, Strategic Thinking, Leadership, Employee Development, Microsoft SQL Server 20002017, Pandas, XlsxWriter, Xlrd, Openpyxl, Pyodbc, SQLAlchemy, Internet Information Services (IIS)',
#  'Title: Assistant Salon Manager - Village at Blanco\nSkills: Communication skills, Motivational attitude, Technical skills, Flexibility, Organization, Goaldriven attitude, Hair cutting license, Cosmetology license, Barber license, Manager training, Incentives, Recognition, Customer base, Ongoing training',
#  'Title: Assistant Salon Manager - Rosedale Marketplace\nSkills: * Cosmetology, * Barber license, * Communication skills, * Motivation, * Technical skills, * Flexibility, * Organization, * Goaloriented, * Hair cutting license, * Salon management, * Leadership, * Team management, * Mentoring, * Customer service, * Training',
#  'Title: Salon Manager - North Villa Park Commons\nSkills: Communication skills, Motivational attitude, Technical skills, Flexibility, Organization, Goaloriented, Driven, Cosmetology or barber license, Manager training, Incentives, Recognition, Existing customer base, Ongoing training opportunities, Career advancement',
#  'Title: Cashier\nSkills: Customer service, Communication skills, Team work, Food preparation, Inventory management, Active listening, Problem solving, Upselling, Refund processing, Honesty, Integrity, Punctuality, Ability to work in a fastpaced environment, Willingness to learn new skills, Ability to handle multiple tasks, Ability to follow instructions, Ability to kneel and lift, Ability to stand for long periods of time',
#  'Title: Restaurant Manager\nSkills: Food preparation, Knowledge of fish and seafood, Customer service, Financial acumen, Quality assurance, Daily operations, Leadership, Integrity, Professionalism, Problemsolving, Ordering, Purchasing, Receiving, Storage, Inventory management, Forecasting, Scheduling, Payroll, Marketing, Sales, Team management, Coaching, Training, Food safety, Sanitation, Liquor laws, Labor laws, Restaurant designs, Restaurant concepts',
#  'Title: Cashier\nSkills: Customer service, Energetic personality, Enthusiastic personality, Lifting, Standing, Bending, Kneeling, Reaching, Pushing, Pulling, Walking, Squatting, Handling job stress, Interacting with others, Working in a flashing and flickering lights environment, Working in a moving mechanical parts environment, Working in a loud noises environment, Working shifts, Minimum age 15, US work eligibility',
#  "Title: Medical Equipment Setup, CSR\nSkills: CPAP setup, Respiratory Assist Devices (RADs) maintenance, CPAP/RAD compliance management, CPAP/RAD supplies management, Insurance verification, Shipping arrangements, Oximetry process management, Safety & Regulatory Manual compliance, Oncall participation, Patient care, Interpersonal communication, Verbal communication, Written communication, Computer literacy, High school diploma or equivalent, Valid driver's license, Equipment Certification Program completion, Lifting and moving up to 25 pounds",
#  'Title: FOOD SERVICE WORKER (PART TIME)\nSkills: Food service, Food preparation, Food safety, Customer service, Sanitation, Health and safety, Ability to work in a fastpaced environment, Ability to work independently and as part of a team, Ability to follow instructions, Ability to maintain a clean and organized work area, Ability to lift and carry heavy objects, Ability to work with knives and other sharp objects, Ability to work in a hot and humid environment',
#  'Title: Controller\nSkills: Accounting, GAAP, SEC regulations, Business unit accounting, Management reporting, Operational improvement, Financial reporting, External auditing, SOX compliance, General ledger, Accounting policies and procedures, Consolidation, LIFO accounting, Goodwill accounting, Intangible asset accounting, Impairment analysis, Selfinsurance reserves accounting, Revenue recognition accounting, Sharebased compensation accounting, Comprehensive income accounting, EPS calculation and accounting, Defined benefit plan accounting, 10Q 10K filings, SAP, Inventory accounting, Inter/intra company accounting, Income tax accounting, Allowance for doubtful accounts, Excess and obsolete inventory, Budgeting, M&A due diligence, Financial integration, Leadership development, Talent management, Team building, CPA certification',
#  'Title: First Year Tax Professional\nSkills: Tax interviews, Tax returns, Business growth, Client retention, Teamwork, Collaboration, IRS compliance, High school diploma, Customer service, Retail, Sales, Marketing, Fastpaced environment, Medical coverage, 401k plan, Employee stock purchase plan, Tax prep benefit, Flexible/remote work, Diversity and inclusion, Equal opportunity employer',
#  'Title: Porter On Call\nSkills: Janitorial services, Cleaning, Vacuuming, Sweeping, Mopping, Stripping, Buffing, Waxing, Dusting, Scrubbing, Sanitizing, Emptying trash cans, Washing, Drying windows, Requesting cleaning supplies, Reporting breakages, Assisting building management, Working on a team, Working independently, Strong report writing, Clear verbal communication, High School diploma',
#  "Title: Administrative Assistant\nSkills: Microsoft Office Suite (Outlook Excel PowerPoint Word), Timekeeper system, Bachelor's degree in Human Resources Business Communication or related field, Strong verbal and written communication, Ability to prioritize think independently and problem solve, Ability to work with others and collaborate across the organization, Selfstarter motivated and proactive, Strong organization skills detail oriented and ability to handle multiple tasks and assignments, Easily multi task and manage multiple projects, Ability to process track and manage attendance and cash handling (variance) discipline, Ability to attend weekly communication meetings with HR Manager and respective management team to review Team Members attendance/variance record, Intermediate knowledge of Excel",
#  'Title: Medical Coder\nSkills: Medical Coding, EPIC PB, ICD10, HCPC, CPT4, Research, Problemsolving, Auditing, Quality Assurance, Compliance, Billing, Reimbursement, Payor Guidelines, Provider Education',
#  'Title: Remote Medical Coder\nSkills: Inpatient/Outpatient, Physician Based Coding, CCS, RHIT, RHIA, CPC, COC, CCSP, Coding, Medical Terminology, Anatomy, Physiology, Disease Process, Pharmacology, Surgical Procedures, Medical Abbreviations, Hospital Information Systems, Encoders, Virtual Work Environment, HIPAA Security Standards, Ethical Coding, AHIMA Guidelines',
#  "Title: Account Executive - Online Division - Grand Canyon University\nSkills: Account Management, Business Development, Communication, Coaching, Microsoft Office Suite, CRM tools, Time Management, Travel, Bachelor's Degree, Exceptional Communication Skills, Strategic Planning, Execution, Partnership Building, Counseling, Student Success, Emotional Intelligence, Clear Communication Skills, SelfMotivation, Empathy, Computer Literacy, Driving License",
#  'Title: LVN - Beverly Hills - OB/GYN Clinic\nSkills: LVN license, Basic patient care and treatment (taking vitals diagnostic testing phlebotomy specimen collection), Patient documentation, Patient advocacy, BLS from American Heart Association or American Red Cross, IV/Phlebotomy certification, Experience as licensed vocational nurse (LVN) in an outpatient setting, Experience in OB/GYN, Outpatient setting, Ambulatory care setting',
#  'Title: LEAD SALES ASSOCIATE-FT\nSkills: Customer service, Communication skills, Safety policies and practices, Ability to follow planograms, Mathematical calculations, Cash register operation, Cash control policies, Deposit control, Driving, High school diploma, Supervisory experience, Physical strength, Lifting, Climbing, Fastpaced environment, Noise level, Outside weather conditions',
#  'Title: Service Technician\nSkills: Wind turbine maintenance, Troubleshooting, Siemens Gamesa, Electrical, Mechanical, Industrial, Renewable energy, Wind technical program, Hydraulic maintenance, Federal law, Executive Order 11246, Pay Transparency Nondiscrimination Provision, California Privacy Notice',
#  'Title: Bar/Shift Lead\nSkills: Hospitality, Customer Service, Management, Craft Beer Knowledge, Willingness to Learn, Front of House, Back of House, Kitchen, Floor, Bar, Craft Beer, 401k, Retirement, Safe Harbor Matching Contribution, Staff Discount, Paid Breaks, 4Week Sabbatical, Enhanced Sick Pay, Healthcare, Life Assurance, High Street Retail Discounts, Employee Assistance Programs, Enhanced Family Friendly Policies, Maternity Leave, Paternity Leave, Holiday Days, Pawternity Leave, DE+I and Crew Forum Groups, "Shifty" Crew Beer',
#  'Title: Assistant Salon Manager - Merriam Town Center\nSkills: Hairstyling, Communication, Motivation, Organization, Drive, Cosmetology, Barber',
#  'Title: Medical Technologist MT or MLT\nSkills: Medical Technology, Medical Laboratory Technician, MT/CLS (ASCP), MLT/CLS (ASCP), Blood Bank, Clinical Laboratory Tests, Data Analysis, Diagnosis, Disease Treatment, Equipment Operation and Maintenance, Laboratory Equipment, FastPaced Work Environment, HighVolume Lab Experience',
#  'Title: On-Demand: Guest Advocate (Cashier), General Merchandise, Fulfillment (T3365)\nSkills: Guest service, Retail business fundamentals, Inventory management, Process efficiency, Daily/weekly workload support, Sales goals, Communication, Teamwork, Ability to work independently, Problemsolving, Attention to detail, Multitasking, Safety and compliance, Cash register operations, Ladder climbing, Merchandise handling, Flexible work schedule, Regular attendance, Active engagement, myTime mobile app, ADA compliance',
#  'Title: PT Customer Lead\nSkills: Customer service, Cashier, Frontend operations, Cash handling, Scanning, Bagging, Cleaning, Maintenance, Communication, Problemsolving, Attention to detail, Physical strength and endurance, Computer literacy, Smart devices, Cash register, Lottery machine, Scanner, Calculator, High school diploma or equivalent, Ability to learn multiple tasks, Ability to meet physical requirements, Ability to meet volume activity standards, Ability to tolerate extreme hot/cold temperatures, Sufficient visual ability',
#  "Title: IT Project Manager  ERP\nSkills: Project Management, PMBOK, Agile, Oracle ERP, Project Charter, Project Plans, Critical Issues Log, Waterfall, MS Office Suite, PMP, Bachelor's Degree, PM Consulting, Process Improvement, ERP Implementation, Systems Configuration, Business Analysis, Business Requirements Documents (BRD), Project Management Mentoring, Project Management Training, Customer Service, Empathy, Triple Constraints, Executive Presence, Documentation, ClientFacing Communication, Internal Communication",
#  'Title: First Year Tax Professional\nSkills: Tax preparation, Tax interviews, Sales, Teamwork, Communication, Retail customer service, Tax expertise, IRS and state requirements, High school diploma, Fastpaced environment, 20 hours per week during peak season, Medical coverage, 401k, Tax prep benefit, Remote opportunities',
#  'Title: Registered General Nurse- Night Shifts\nSkills: Nursing, Patient assessment and monitoring, Medication and treatment administration, Assisting in surgeries and postoperative care, Patient record keeping, Emotional support provision, Team collaboration for care plan development, Patient health management and medication education, Advocacy for patient wellbeing and rights, Patient safety and infection control measures, Medical advancements and best practices awareness, NMC registration, 6 months UK healthcare experience, Proof of right to work in the UK, UK references, NHS, Private sector',
#  'Title: Executive Assistant\nSkills: Microsoft Office, PowerPoint, Writing, Editing, Proofreading, Scheduling, Project management, Presentation, Agenda creation, Transcribing, Reporting, Data analysis, Data visualization, Board meeting support, Senior management support, Executive assistance',
#  'Title: First Year Tax Professional\nSkills: Customer service, Retail, Sales, Marketing, Teamwork, Collaboration, High school diploma, Communication, IRS requirements, Tax preparation, Tax laws, Accounting, Finance, Microsoft Office, Personal finance, Problemsolving, Time management, Attention to detail, Accuracy, Ethics, Professionalism',
#  'Title: Lead Administrative Support Assistant (Assistant to Chief Nurse Executive)- FSH\nSkills: Care Ware, Timekeeping software, Microsoft Office Suite, Multidisciplinary collaboration, Process improvement, Autonomy, Selfmotivation, Teamwork, Creativity, Resourcefulness, Time management, Verbal communication, Written communication, Interpersonal communication, Adaptability, Dependability, Facility practices, Rules and regulations, Case management, Conflict resolution, Presentation software',
#  'Title: Patient Care Tech-General Medicine Part-time Days\nSkills: CPR, Capillary Blood Glucose Monitoring, Basic Life Support, Unit Based Recognition, Health and Safety Training, Hospital Equipment and Supplies, High School Diploma, Patient Care, Patient Care Technician, CNA Certification, Indirect Patient Care, Nursing Care Procedures, Medical Terminology, Communication, Teamwork, ProblemSolving, Critical Thinking, Time Management, Professionalism, Accuracy, Attention to Detail, Compassion, Empathy, Ethics',
# ...
#  'Title: Captain\nSkills: Nonverbal communication, Hospitality, Fine dining, Wine & spirits, Problem solving, Communication, Restaurant management, Food bank, Popup kitchen, Casual dining',
#  'Title: Staff Accountant\nSkills: Financial Accounting, Journal Entries, Bank Reconciliation, Balance Sheet Analysis, Microsoft Excel, Strong Analytical Skills, Interpersonal and Communication Skills, Ownership of Role, Deadline Management, Multitasking, Accounting Degree, Strong Accounting Skills, Attention to Detail',
#  'Title: Audit Senior\nSkills: Accounting software, GAAP, Generally accepted auditing standards, Audit procedures, Client communication, CPA certification, Accounting principles, Financial statement presentations, Team environment, Analytical abilities, Organizational skills, Oral and written communication, Audit techniques, Incharge engagements, Accounting tasks, Specialized accounting principles',
#  'Title: Buyer\nSkills: Procurement, Purchasing, Supplier Relationship Management, Vendor Sourcing, Price Analysis, Cost Analysis, Procurement Process Improvement, Compliance, Data Analysis, MS Office, Excel, Communication, Interpersonal Skills, Multitasking, Prioritization, UK Procurement Regulations',
#  'Title: IT Project Manager\nSkills: Program Management, Functional Requirements Document (FRD), Functional Design Package (FDP), Regulatory Reporting, Project Planning and Execution, Vendor Contract and Relationship Management, Project Governance, JobAides and Training Material, Production and Closeout, Retrospect, Executive Summary, Process Maturity Plan/Roadmap, Stakeholder Alignment, RACI, Project Charter, Technical Prerequisite Planning, Vendor and Stakeholder Alignment, Performance monitoring, Vendor Functional Requirements Document, MSA, SOW, EndUser JobAides, Training PowerPoints, Process Guides',
#  'Title: Kitchen Prep\nSkills: Food preparation, Food handling, Sanitation, Kitchen equipment, Plating recipes, Menu knowledge, Safety procedures, Teamwork, Dependability, Detailoriented, Multitasking, Physical stamina, Lifting, Carrying, Reaching, Bending, Stooping, Tasting, Smelling, Visual acuity, Verbal communication',
#  'Title: Controller\nSkills: Accounting, Financial Analysis, Budgeting, Forecasting, Balance Sheets, Income Statements, Cash Flow Statements, Variance Analysis, Financial Reporting, General Ledger, Reconciliations, Financial Controls, Software Systems, Cash Flow Management, Payroll, Tax Accounting, QuickBooks, Yardi, Financial Management Systems, Advanced Excel, Commercial Construction, Real Estate Development, Draw Requests, AIA Forms, CPA',
#  "Title: Sous Chef\nSkills: Cooking, Food Preparation, Menu Planning, Food Safety, Kitchen Management, Sanitation, Food Handling, High School Diploma, Two Years of Experience in Institutional Cooking, Empathy for Recovering Persons, Light to Heavy Lifting, Valid Driver's License",
#  'Title: Senior CAD Designer\nSkills: Mechanical Design, SolidWorks, Sheet Metal Design, CAD Modeling, ePDM, HVAC Components, Standardization, Modularization, Automation, Lean Principles, BOM Management, ISO Procedures, Product Release, Associates Degree in Mechanical Design, Certified SolidWorks Expert, Mathematical Aptitude, Mechanical Aptitude, Organizational Skills, PC Skills, Word, Excel, Communication Skills, Interpersonal Skills, Self Motivation, Team Environment',
#  'Title: Web Architect\nSkills: HTML, CSS, PHP, JSP, JavaScript, DHTML, Web services, XML, HTTP, Mobile development, Web development, PhoneGap, Sencha, Handlebars, Moustache, Angular, React, Node, REST, JSON, Java, React.Js, Node.js, Vue.js, MVC, MVP, MVVM',
#  "Title: Research Geneticist\nSkills: Genetics, Bioinformatics, Genomics, Computational biology, Plant breeding, Degree in genetics or related field, Graduate education in genetics or related field, EVerify employment verification, Direct Deposit, Selective Service registration or exemption, Office of Personnel Management (OPM) Qualification Standard's requirements, Telework up to four days per week, Flexible work arrangements",
#  "Title: Customer Service Rep\nSkills: Customer Service, Data Entry, Data Processing, Inventory Management, Key Account Management, Communication, Microsoft Excel, High School Diploma, Bachelor's Degree, Associate's Degree, Microsoft Office Suite, Manufacturing, Commercial Printing",
#  'Title: Pasta Maker\nSkills: Pasta making, Bread making, Pastry making, Food preparation, Collaboration, Communication, Time management, Problem solving, Team work, Cleanliness, Hygiene, Mobility, Lifting, Customer service, Attention to detail, Flexibility, Food safety, Safety standards',
#  "Title: Rental Sales Agent\nSkills: Exceptional interpersonal skills, Verbal communication, Written communication, Organizational skills, Multitasking, Ability to handle stress, Customer service, Sales, Rental agreement, Vehicle upselling, Administrative tasks, Telephone communication, Email communication, Company uniforms, Travel, High school diploma, Customer service experience, Sales experience, Driver's license, Sales quotas, Service processes, Language proficiency",
#  'Title: Family Law Attorney\nSkills: Family Law, Litigation, Divorce, Domestic Violence, Paternity, Custody, Visitation, Support, Protective Orders, Research, Writing, Analytical Skills, Depositions, Mediation, Hearings, Legal Documents, Time Management, Client Communication, Communication, Billable Hours, Case Management, CFLS',
#  'Title: Family Law Attorney\nSkills: Family law, Litigation, Client sourcing, Collections, Intake, Marketing, Vetting, Legal care',
#  'Title: Food Captain\nSkills: Food Category expert, Food operational execution, Train store associates, Food execution production replenishment ordering organization sanitization and customer service, Plan and execute food sampling, Conduct and lead in store training, Follow up with and conduct refresher training activities, Ensure foodservice areas are stocked and food rotated using FIFO method of food rotation, Follow current Planogram, Order food products, Monitor shrink while improving sales, Identify suggest train and continuously collaborate with BUQAS training personnel, Food safety practices and procedures, Conduct needs analysis, Operate within budgeted expectations, High school diploma or equivalate, Education/instructional or equivalent retail training experience, Leading or supervisory experience, Experience in training leadership team building, Skills in collaboration cooperation communication and organization, Food Manager Certification ServSafe NRFSP, Strong communication skills in English, French skills, Customer serviceoriented, Delivering within deadlines, Communicating effectively with customers management associates and vendors',
#  'Title: Staff Nurse\nSkills: Medical Billing, Clinical Informatics, Patient Education, Microsoft Office Suite, Database Management, Computer Hardware, Vascular Access Devices, Nursing, IV Therapy, RN License, BLS Certification',
#  'Title: Metal Manager\nSkills: Supply Chain Management, Metal Management, Forecasting, Inventory Management, Raw Material Planning, Procurement, Supplier Qualification, Communication, Teamwork, SAP/Oracle, Performance Management, Business Analysis, Microsoft Office, Presentation Skills, Lean Manufacturing, ProblemSolving, Analytical Skills, Leadership, Change Management, Lean Six Sigma Black Belt, SQL, Export Administration Regulations (15 C.F.R. 730 et seq.), International Traffic in Arms Regulations (ITAR)',
#  "Title: Urban Planner II\nSkills: Urban Design, Architecture, Building Codes, City Planning, Community Development, GIS, Land Use Regulations, Zoning Regulations, Microsoft Office Suite, Project Management, AutoCAD, Public Speaking, Analytical Thinking, Communication, Time Management, Problem Solving, Team Work, Bachelor's Degree in Urban Planning Engineering Public Administration Public Policy or Related Field, 3 Years of Experience in Technical Review of Site Plans and Architectural Elevations, Master's Degree in Urban Planning Urban Design Engineering Architecture Public Administration Public Policy or Related Field, 35 Years of Experience in Technical Review of Site Plans and Architectural Elevations, Some Supervisory Experience, Valid Georgia Driver's License, American Institute of Certified Planners (AICP) Certification (Preferred)",
#  'Title: Assistant Plant Manager\nSkills: Production, Facility Maintenance, Safety, Merchandise Product Lines, Training, Strong knowledge of construction industry',
#  'Title: Aquatics Specialist\nSkills: Animal welfare, Aquatic care, Husbandry, Verbal communication, Written communication, Pointofsale service, Cash sales, Credit and check sales, Returns and exchanges, Cash drawer balance, Guest carryout service, Merchandise handling (up to 50 pounds), Honesty and integrity, Evening and weekend work',
#  "Title: Senior Air Consultant\nSkills: Air Quality Permitting, Air Quality Compliance, Air Pollution Dispersion Modeling, Statistical Analysis, Geospatial Analysis, Air Quality Data Analysis, Pollution Control Measures, Air Monitoring, Indoor Air Quality Analysis, Environmental Impact Reports, Environmental Regulations, Client Relationship Management, Mentoring, Spreadsheets, Word Processing, Environmental Science, Atmospheric Science, Chemistry, Physics, Programming, Database, GIS, Multitasking, Flexibility, Travel, Independent Work, EIT Certification, P.E. Certification, Team Work, Learning and Growth Mindset, Travel (up to 30%), Valid Driver's License",
#  "Title: Internal Auditor\nSkills: Auditing, Corporate Audits, Policy and Regulatory Compliance, Capital Markets Experience, Interest Rates, Investment Risk Management, Liquidity Risk Management, Accounting, Finance, Economics, Statistics, Bachelor's Degree, 12 Years Related Professional Experience, Medical and Dental Insurance, Paid Vacation and Sick Leave, Wellness Program, 401K Matching, Bonus Opportunity",
#  'Title: Shift Supervisor\nSkills: Cash handling, Customer interaction, Cashier procedures, Race safety, Kart maintenance, Company policies, Retail merchandise, Operational paperwork, Safety, Payroll, Facility management, Scheduling, Employee communication, Management reporting, Facility appearance, Facility maintenance, Heavy lifting, Supervisory experience, Previous track record, Customer service skills, Weekend and evening work, Drug test, Background check',
#  'Title: Litigation Attorney\nSkills: Litigation, Law, Legal Research, Trial Preparation, Document Drafting, Motion Practice, Discovery, Legal Writing, Courtroom Experience, Strong Academics, Texas License or Ability to Waive In',
#  'Title: Scientist I\nSkills: HPLC, GC, Karl Fischer titration, Chromatography systems, Mass spectrometry, Vibrational spectroscopy, Analytical chemistry, Analytical methods development, Methods validation, Characterization of compounds, Instrument validation, Pharmaceutical laboratory, Pharmaceutical manufacturing, Continuous manufacturing, API drug substance testing, Finished drug product testing, SOPs, Project management, Team work, Communication skills, Problem solving, Troubleshooting, Data analysis, Report writing, Presentation skills, Attention to detail, Organizational skills, Safety, Cleanliness, Collaboration, Diversity and inclusion, Equal opportunity',
#  'Title: Greeter\nSkills: Interpersonal skills, Fastpaced environment, Verbal communication, Written communication, Organizational skills, Multitasking, Customer service, Handling different situations, Directing customers, Answering customer inquiries, High School Diploma, GED, Customer service experience, Customer support experience, Escalation support experience, Basic computer navigation skills, Microsoft Office Applications, Relationship building skills, At least 21 years old, Flexible schedule, Authorized to work in the United States, Proficiency in English, Proficiency in Spanish, Ability to communicate in other languages, Paid vacation, Medical benefits, Dental benefits, Vision benefits, 401(k), Short Term Disability, Long Term Disability, Basic Life, Supplemental Life, Future growth opportunities, Equal OpportunityAffirmative Action Employer, Minority, Women, Men, Disability, Veteran, Gender Identity, Sexual Orientation, Mobility service provider, Customer contact, Premium service, Advice and sales in exchange, Rental process, Global mobility service provider, Sales, Employees worldwide, Mobility platform, Products, Car rental, Car sharing, Cab, Driver, Chauffeur services, Car subscription, Fleet, Cooperation partners, Drivers worldwide, Franchise partners, Countries, Rental stations, Firstclass customer experience, Outstanding customer service, Entrepreneurship, Longterm stability',
#  'Title: Epidemiologist\nSkills: Epidemiology, Environmental health, Biostatistics, Toxicology, Hazard assessment, Risk assessment, Exposure assessment, Environmental modeling, Metaanalyses, Project management, Staff leadership, Quantitative skills, Doseresponse analysis, Systematic literature reviews, Data extraction, Data synthesis, Technical writing, Proposal writing, Presentation skills, Mentoring, Training, Problemsolving, Attention to detail, Multitasking, Ability to work under pressure',
#  'Title: Department Manager\nSkills: Customer service, Team management, Retail operations, Sales analysis, Visual merchandising, Performance management, Recruitment and training, Store safety and security, Communication and interpersonal skills, Problemsolving and decisionmaking, Attention to detail, Physical stamina and agility, Computer literacy, Multitasking and time management, Leadership and motivation, Adaptability and flexibility, Ability to work independently and as part of a team, Ability to work in a fastpaced environment, Ability to lift and carry heavy objects, Ability to stand for long periods of time, Open availability including evenings and weekends',
#  'Title: Attorney\nSkills: Construction Law, Civil Litigation, Legal Research, Legal Writing, Corporate Law, Commercial Litigation, Drafting, Pleadings, Discovery, Motion Practice, Trial Advocacy, Corporate Governance, Commercial Contracts, Regulatory Compliance, Legal Documents, Briefs, Opinions, Mergers and Acquisitions, Corporate Restructuring, Shareholder Agreements, Contract Disputes, Construction Defects, Intellectual Property Disputes, Dispute Resolution, Juris Doctor Degree, State Bar Admission, ClientFocused Approach, Interpersonal Skills, Communication Skills',
#  'Title: Attorney\nSkills: Attorney, Trial experience, Excellent writing skills, High energy',
#  'Title: Cashier\nSkills: Communication skills, Customer service, Food preparation, Teamwork, Upselling, Inventory management, Problemsolving, Positive attitude, Willingness to learn, Ability to work in a fastpaced environment, Ability to follow instructions, Ability to work multiple stations, Ability to handle product preparation, Ability to kneel and follow proper lifting procedures, Ability to stand during serving customers or at register, Dental insurance, Employee discount, Health insurance, Life insurance, Paid time off, Vision insurance']

# %%
from chromadb import Documents, EmbeddingFunction, Embeddings
from google.api_core import retry

from google.genai import types


# Define a helper to retry when per-minute quota is reached.
is_retriable = lambda e: (isinstance(e, genai.errors.APIError) and e.code in {429, 503})


class GeminiEmbeddingFunction(EmbeddingFunction):
    # def __init__(self, document_mode=True):
    #     self.document_mode = document_mode
    #     self.client = genai

    # @retry.Retry(predicate=is_retriable)
    # def __call__(self, input):
    #     if self.document_mode:
    #         task_type = "retrieval_document"
    #     else:
    #         task_type = "retrieval_query"

    #     # Ensure input is a list of strings (Chroma passes it this way)
    #     response = self.client.embed_content(
    #         model="models/text-embedding-004",
    #         content=input,
    #         task_type=task_type,
    #     )

    #     return [e.values for e in response.embeddings]
    
    # Specify whether to generate embeddings for documents, or queries
    document_mode = True

    @retry.Retry(predicate=is_retriable)
    def __call__(self, input: Documents) -> Embeddings:
        if self.document_mode:
            embedding_task = "retrieval_document"
        else:
            embedding_task = "retrieval_query"

        response = client.models.embed_content(
            model="models/text-embedding-004",
            contents=input,
            config=types.EmbedContentConfig(
                task_type=embedding_task,
            ),
        )
        return [e.values for e in response.embeddings]

# %%
import chromadb

DB_NAME = "skillsdb"

embed_fn = GeminiEmbeddingFunction()
embed_fn.document_mode = True

chroma_client = chromadb.Client()
db = chroma_client.get_or_create_collection(name=DB_NAME, embedding_function=embed_fn)

db.add(documents=documents, ids=[str(i) for i in range(len(documents))])

# %%
db.count()
db.peek(1)
# Out:
# {'ids': ['0'],
#  'embeddings': array([[ 4.60675173e-03,  4.76415968e-04, -6.02308139e-02,
#          -1.63157433e-02,  4.80655953e-02,  1.70870135e-05,
#           2.55073216e-02,  1.13362912e-02, -7.99719896e-03,
#           5.94347790e-02,  8.94606952e-03,  2.68731499e-03,
#           8.55240896e-02, -1.04237664e-02, -4.03682813e-02,
#          -1.39879491e-02,  2.51365602e-02,  1.40086776e-02,
#          -3.23391519e-02, -4.80190217e-02,  3.04118730e-02,
#          -5.12191616e-02,  8.73220060e-03, -4.27141599e-02,
#          -3.18831988e-02,  2.23306827e-02,  1.39725273e-02,
#          -4.29865383e-02, -7.76849464e-02, -7.99402222e-03,
#           4.68154177e-02,  3.20878066e-02, -3.02996896e-02,
#          -2.61285768e-05, -6.58441782e-02, -2.12349161e-03,
#          -2.53288336e-02,  1.01190917e-02,  2.29389202e-02,
#           3.57679166e-02, -8.80975928e-03, -4.30099666e-02,
#          -7.29357004e-02,  2.59263441e-02,  2.42373217e-02,
#           2.26951838e-02,  3.09228264e-02, -2.50500627e-02,
#           4.56640348e-02, -7.99560919e-04,  1.71008352e-02,
#           2.41230801e-02, -7.63966218e-02,  3.49765792e-02,
#          -1.04890307e-02, -2.95099709e-02, -5.29215224e-02,
#          -3.62232439e-02, -3.09871230e-03,  9.29304305e-03]]),
#  'documents': ["Title: Systems Administrator\nSkills: Windows computing, Server 2012, Software troubleshooting, Analytical thinking, Problem solving, PowerShell, Customer service, Microsoft Office 365, Azure AD, SharePoint, Security and Compliance Center, Teams, MCSE, MCSA, Bachelor's degree"],
#  'uris': None,
#  'data': None,
#  'metadatas': [None],
#  'included': [<IncludeEnum.embeddings: 'embeddings'>,
#   <IncludeEnum.documents: 'documents'>,
#   <IncludeEnum.metadatas: 'metadatas'>]}

# %%
# Switch to query mode when generating embeddings.
embed_fn.document_mode = False

# Search the Chroma DB using the specified query.
query = "What skills are needed for a Data Engineer?"

result = db.query(query_texts=[query], n_results=1)
[all_passages] = result["documents"]

Markdown(all_passages[0])
# Out:
# Title: Software Engineer
# Skills: SQL, Python, Django, HTML, CSS, JavaScript, Bootstrap, Microsoft Visual C# .net, Microsoft Visual Basic .net, VBScript, ETL, SSIS, DTS, Azure DevOps, Production Support, Healthcare, Teamwork, Collaboration, Respect, Member Centric, Honesty, Integrity, Commitment to Service Excellence, Compassion, Empathy, Problem Solving, Initiative, SelfDirected, Flexibility, Adaptability, Communication, Strategic Thinking, Leadership, Employee Development, Microsoft SQL Server 20002017, Pandas, XlsxWriter, Xlrd, Openpyxl, Pyodbc, SQLAlchemy, Internet Information Services (IIS)

# %%
query_oneline = query.replace("\n", " ")

# This prompt is where you can specify any guidance on tone, or what topics the model should stick to, or avoid.
prompt = f"""You are a helpful and informative bot that gives advice on skills needed for a specific job using text from the reference job posting included below. 
Be sure to respond in a complete sentence, being comprehensive, including all relevant background information. If the passage is irrelevant to the answer, you may ignore it.

QUESTION: {query_oneline}
"""

# Add the retrieved documents to the prompt.
for passage in all_passages:
    passage_oneline = passage.replace("\n", " ")
    prompt += f"PASSAGE: {passage_oneline}\n"

print(prompt)
# Out:
# You are a helpful and informative bot that gives advice on skills needed for a specific job using text from the reference job posting included below.
# Be sure to respond in a complete sentence, being comprehensive, including all relevant background information. If the passage is irrelevant to the answer, you may ignore it.
#
# QUESTION: What skills are needed for a Data Engineer?
# PASSAGE: Title: Software Engineer Skills: SQL, Python, Django, HTML, CSS, JavaScript, Bootstrap, Microsoft Visual C# .net, Microsoft Visual Basic .net, VBScript, ETL, SSIS, DTS, Azure DevOps, Production Support, Healthcare, Teamwork, Collaboration, Respect, Member Centric, Honesty, Integrity, Commitment to Service Excellence, Compassion, Empathy, Problem Solving, Initiative, SelfDirected, Flexibility, Adaptability, Communication, Strategic Thinking, Leadership, Employee Development, Microsoft SQL Server 20002017, Pandas, XlsxWriter, Xlrd, Openpyxl, Pyodbc, SQLAlchemy, Internet Information Services (IIS)

# %%
answer = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=prompt)

Markdown(answer.text)
# Out:
# Based on the job posting, the skills needed for a Data Engineer include SQL, Python, ETL, SSIS, DTS, Azure DevOps, Pandas, XlsxWriter, Xlrd, Openpyxl, Pyodbc, and SQLAlchemy.

# %% [markdown]
# # Section 4: Evaluation

# %%
import enum

# Define the evaluation prompt
SUMMARY_PROMPT = """\
# Instruction
You are an expert evaluator. Your task is to evaluate the quality of the responses generated by two AI models. We will provide you with the user input and a pair of AI-generated responses (Response A and Response B).
You should first read the user input carefully for analyzing the task, and then evaluate the quality of the responses based on the Criteria provided in the Evaluation section below.
You will first judge responses individually, following the Rating Rubric and Evaluation Steps.
Then you will give step-by-step explanations for your judgment, compare results to declare the winner based on the Rating Rubric and Evaluation Steps.

# Evaluation
## Metric Definition
You will be assessing groundedness, which measures the ability to provide or reference information included only in the user prompt.

## Criteria
Groundedness: The response contains information included only in the user prompt. The response does not reference any outside information.

## Rating Rubric
"A": Response A is more grounded than Response B.
"SAME": Both response A and B are equally grounded, or ungrounded.
"B": Response B is more grounded than Response A.

## Evaluation Steps
STEP 1: Analyze Response A based on the groundedness criteria: Identify any information in the response not present in the prompt and provide assessment according to the criterion.
STEP 2: Analyze Response B based on the groundedness criteria: Identify any information in the response not present in the prompt and provide assessment according to the criterion.
STEP 3: Compare the overall performance of Response A and Response B based on your analyses and assessment.
STEP 4: Output your preference of "A", "SAME" or "B" to the pairwise_choice field according to the Rating Rubric.
STEP 5: Output your assessment reasoning in the explanation field.

# User Inputs and AI-generated Responses
## User Inputs
### Prompt
{prompt}

## AI-generated Responses

### Response A
{baseline_model_response}

### Response B
{response}
"""

# Define a structured enum class to capture the result.
class SummaryRating(enum.Enum):
  VERY_GOOD = '5'
  GOOD = '4'
  OK = '3'
  BAD = '2'
  VERY_BAD = '1'


def eval_summary(prompt, baseline_model_response, ai_response):
  """Evaluate the generated summary against the prompt used."""

  chat = client.chats.create(model='gemini-2.0-flash')

  # Generate the full text response.
  response = chat.send_message(
      message=SUMMARY_PROMPT.format(prompt=prompt, baseline_model_response= baseline_model_response, response=ai_response)
  )
  verbose_eval = response.text

  # Coerce into the desired structure.
  structured_output_config = types.GenerateContentConfig(
      response_mime_type="text/x.enum",
      response_schema=SummaryRating,
  )
  response = chat.send_message(
      message="Convert the final score.",
      config=structured_output_config,
  )
  structured_eval = response.parsed

  return verbose_eval, structured_eval


text_eval, struct_eval = eval_summary(prompt=prompt, baseline_model_response = baseline_response, ai_response = answer.text)
Markdown(text_eval)
# Out:
# STEP 1: Response A is completely irrelevant to the prompt. All information is not from the provided passage.
# STEP 2: Response B provides relevant information from the passage.
# STEP 3: Response B is more grounded than response A because response A does not contain any information from the passage.
# STEP 4: B
# STEP 5: Response A is completely irrelevant to the prompt. Response B is more grounded as all listed skills are directly from the provided job posting.
